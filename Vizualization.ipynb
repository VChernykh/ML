# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('score.csv')

# %%
df = df.rename(columns={'math score':'math_score'})

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math_score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.hist('math_score')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023DBF744B00>]],
#       dtype=object)

# %%
df.plot.scatter(x='reading score', y='math_score')

# %%
graf = sns.lmplot(x='reading score', y='math_score', hue = 'gender', data = df, fit_reg=False)
graf.set_xlabels('read_score')

# %%
inc = pd.read_csv('income.csv')

# %%
inc.plot(kind='line')

# %%
inc['income'].plot()

# %%
inc.income.plot()

# %%
inc.plot()

# %%
sns.lineplot(x=inc.index, y=inc.income)

# %%
plt.plot(inc.index, inc.income)

# %%
sns.lineplot(data=inc)

# %%
df = pd.read_csv('genome_matrix.csv')
df = df.drop(['Unnamed: 0'], axis=1)

# %%
g = sns.heatmap(data=df, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
sns.lmplot(x='x', y='y', data=df)

# %%
dota = pd.read_csv('dota_hero_stats.csv')

# %%
nums = [i.count(',') + 1 for i in dota.roles]

# %%
dota = dota.assign(num = nums)

# %%
dota.num.hist()

# %%
iris = pd.read_csv('iris.csv')

# %%
for i in iris.columns[1:-1]:
    plt.figure()
    sns.distplot(iris[str(i)])

# %%
sns.violinplot(x=iris['petal length'])

# %%
sns.pairplot(iris)

# %%
d = {'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]}
df = pd.DataFrame(data=d)

# %%
my_stat = pd.read_csv('my_stat.csv')

# %%
df = pd.read_csv('my_stat.csv')

subset_1 = my_stat.iloc[list(range(10)), [0, 2]]
subset_2 = my_stat.iloc[:, [1, 3]]
subset_2 = subset_2.drop([0, 4], axis=0)

# %%
my_stat
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# 5     2  11.0  A  0.0
# 6     0   9.0  A  2.0
# 7     1   9.0  A  1.0
# 8     0   9.0  B  2.0
# 9    -1  10.0  A  0.0
# 10    1  10.0  A  1.0
# 11   -2  10.0  A  1.0
# 12    0   8.0  B  0.0
# 13    1  12.0  A  3.0
# 14   -1  10.0  A  2.0
# 15    2  10.0  B  1.0
# 16    0   9.0  B  1.0
# 17    0  11.0  A  0.0
# 18    0   8.0  A  1.0
# 19    0  10.0  A  1.0
# 20    1  10.0  B  2.0
# 21    3  10.0  A  2.0
# 22   -2  12.0  A  3.0
# 23   -1  11.0  B  3.0
# 24    2   8.0  B -0.0
# 25    2  10.0  A  3.0
# 26    2  12.0  A  1.0
# 27    2   9.0  A  1.0
# 28   -2  10.0  B  0.0
# 29    0   8.0  A  1.0
# ..   ..   ... ..  ...
# 470   0   9.0  A -0.0
# 471  -1  10.0  B  2.0
# 472   3   9.0  B  1.0
# 473  -1  10.0  B  1.0
# 474   0   9.0  B  1.0
# 475  -1  10.0  B  2.0
# 476   0  10.0  B  0.0
# 477  -2  12.0  B  2.0
# 478   1   9.0  B -0.0
# ...

# %% [markdown]
# Выборка двумя способами

# %%
subset_1 = my_stat[(my_stat['V1'] > 0) & (my_stat['V3'] == 'A')]
subset_2 = my_stat.query('V1 != 10 or V4 >= 1')

# %% [markdown]
# Новые столбцы

# %%
my_stat = my_stat.assign(V5 = my_stat.V4 + my_stat.V1)
my_stat = my_stat.assign(V6 = np.log(my_stat.V2))
# Out:
#      V1    V2 V3   V4        V6
# 0     2  13.0  B  1.0  2.564949
# 1    -1   7.0  B  1.0  1.945910
# 2     0  11.0  A  0.0  2.397895
# 3     2  11.0  A  2.0  2.397895
# 4     0  10.0  B -1.0  2.302585
# 5     2  11.0  A  0.0  2.397895
# 6     0   9.0  A  2.0  2.197225
# 7     1   9.0  A  1.0  2.197225
# 8     0   9.0  B  2.0  2.197225
# 9    -1  10.0  A  0.0  2.302585
# 10    1  10.0  A  1.0  2.302585
# 11   -2  10.0  A  1.0  2.302585
# 12    0   8.0  B  0.0  2.079442
# 13    1  12.0  A  3.0  2.484907
# 14   -1  10.0  A  2.0  2.302585
# 15    2  10.0  B  1.0  2.302585
# 16    0   9.0  B  1.0  2.197225
# 17    0  11.0  A  0.0  2.397895
# 18    0   8.0  A  1.0  2.079442
# 19    0  10.0  A  1.0  2.302585
# 20    1  10.0  B  2.0  2.302585
# 21    3  10.0  A  2.0  2.302585
# 22   -2  12.0  A  3.0  2.484907
# 23   -1  11.0  B  3.0  2.397895
# 24    2   8.0  B -0.0  2.079442
# 25    2  10.0  A  3.0  2.302585
# 26    2  12.0  A  1.0  2.484907
# 27    2   9.0  A  1.0  2.197225
# ...

# %% [markdown]
# Переименовал

# %%
my_stat = my_stat.rename(columns={'V1': 'session_value', 'V2' : 'group', 'V3' : 'time', 'V4' : 'n_users'})

# %% [markdown]
# NA

# %%
my_stat = pd.read_csv('my_stat_na.csv')
my_stat.head()
# Out:
#    group  n_users  session_value time
# 0    9.0     -9.0            1.0    A
# 1   10.0      8.0            2.0    B
# 2   10.0     -1.0            4.0    A
# 3   10.0     -0.0            0.0    B
# 4    9.0    -15.0           -1.0    B

# %%
my_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# group            500 non-null float64
# n_users          500 non-null float64
# session_value    500 non-null float64
# time             500 non-null object
# dtypes: float64(3), object(1)
# memory usage: 15.7+ KB

# %%
my_stat = my_stat.assign(session_value = my_stat.session_value.fillna(0))

# %%
mean = my_stat[(my_stat.n_users >= 0.0)].n_users.median()
mean
# Out:
# 7.0

# %% [markdown]
# Редактивароние dataframe

# %%
my_stat.loc[my_stat.n_users <= -0.0, 'n_users'] = med

# %% [markdown]
# Groupby

# %%
my_stat = my_stat.assign(session_value = my_stat.session_value.fillna(0))
tab = my_stat.groupby('group',as_index = False).agg({'session_value':'mean'})
tab = tab.rename(columns={'session_value':'mean_session_value'})
mean_session_value_data = tab

# %%
tab.columns
# Out:
# Index(['group', 'session_value'], dtype='object')

# %%
pd.Index(list(range(len(tab))))
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
tab.set_index(pd.Index(list(range(len(tab)))), 'group')
# Out:
#    session_value
# 0       0.000000
# 1      -0.294118
# 2       0.151786
# 3      -0.047368
# 4       0.112000
# 5      -0.382353
# 6       0.000000
